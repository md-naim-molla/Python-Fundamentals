# %% [markdown]
# # 1. Python Output

# %%
print('hi')

# %% [markdown]
# # 2. Data Types

# %%
# Integer

# %%
# Decimal/Float

# %%
# Boolean

# %%
# Text/String

# %%
# complex

# %%
# List

# %%
# Tuple)

# %%
# Sets

# %%
# Dictionary

# %% [markdown]
# # 3. Variables

# %%
# Dynamic Typing
# Static Typing

# %%
# Dynamic Binding
# Static Binding

# %%
# Styling decoration

# %% [markdown]
# # Comments

# %%
# this is a comment

# %% [markdown]
# # 4. Keywords & Identifiers

# %%
# Keywords
# Out:
# 35

# %%
# Identifiers

# %% [markdown]
# # 5. User Input

# %% [markdown]
# # 6. Type Conversion

# %%
# Implicit Vs Explicit

# %% [markdown]
# # 8. Operators

# %%
# Arithmetic

# %%
# Relational

# %%
# Logical

# %%
# Assignment

# %%
# Membership

# %% [markdown]
# # 9. If-Else
